# %% [markdown]
# <h1> Eptiope Prediction </h1>
# <h3> Benjamin Schubert </h3>
#
# This tutorial illustrates the use of Fred2 to predict HLA-I/II epitopes and how to analyse results.

# %%
import sys 

#is is needed as long as Fred2 is not installed properly
sys.path.add()
